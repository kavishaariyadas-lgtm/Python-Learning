# %%
age=int(input("Enter the age ?"))
if age>18:
    print("Adult")
else:
    print("Minor")
# Out:
# Enter the age ? 6
# Minor

# %%
marks=70
if marks>50:
     print("Pass")
else:
     print("Fail")
# Out:
# Pass

# %%
marks=70
if marks >= 75:
    print("A Grade")
elif marks >= 65:
    print("B Grade")
elif marks >= 50:
    print("C Grade")
else:
    print("F")
# Out:
# B Grade

# %%
number=-12
if number>0:
    print("Possitive")
elif number<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
number=6
if number>0:
    print("Possitive")
elif number<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Possitive

# %%
number=int(input("Enter the number ?"))
if number%2==1:
    print("Odd")
else:
    print("Even")
# Out:
# Enter the number ? 21
# Odd

# %%
name=input("Enter the name ?")
marks=int(input("Enter the marks ?"))
print("Entered marks are:",marks)
if marks >= 75:
    print("A")
elif marks >= 65:
    print("B")
elif marks >= 50:
    print("C")
else:
    print("F")
# Out:
# Enter the name ? Kavisha
# Enter the marks ? 72
# Entered marks are: 72
# B

# %%
marks=int(input("Enter the marks(0-100) ? "))
if marks >= 90 and score <=100:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
elif marks >= 60:
    print("D")
elif marks >= 0:
    print("F")
else:
    print("Invalid number endered")
# Out:
# Enter the marks(0-100) ?  74
# C
