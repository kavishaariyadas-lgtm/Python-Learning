# %% [markdown]
# # Python
# ## Day01

# %%
print("Hello IIT")
# Out:
# Hello IIT

# %%
print("Hi Sri Lanka")
# Out:
# Hi Sri Lanka

# %%
print('Hi Sri Lanka')
# Out:
# Hi Sri Lanka

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("My name is Kavisha Ariyadas")
print("I am a student")
print("I am learning python")
# Out:
# My name is Kavisha Ariyadas
# I am a student
# I am learning python
