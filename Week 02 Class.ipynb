# %%
X=10

# %%
print(type(X))
# Out:
# <class 'int'>

# %%
x=100

# %%
print(type(X))
print(x)
# Out:
# <class 'int'>
# 100

# %%
y="Kavisha"

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
z=15.66

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
is_student=True

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
_myname="Kavisha"

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
my_name=input("What is your name ?")
print(my_name)
# Out:
# What is your name ? Kavisha
# Kavisha

# %%
number1=int(input("Enter the first number?"))
number2=input("Enter the second number?")
print(number1)
print(number2)
print(type(number1))
print(type(number2))
# Out:
# Enter the first number? 100
# Enter the second number? 200
# 100
# 200
# <class 'int'>
# <class 'str'>

# %%
quantity_available=10
print(type(quantity_available))
# Out:
# <class 'int'>

# %%
pet_name=input("Enter the pet_name?")
home_town=input("Enter the home_town?")
dream_job=input("Enter the dream_job?")

print(type(pet_name))
print(type(home_town))
print(type(dream_job))
# Out:
# Enter the pet_name? Grace
# Enter the home_town? Vavuniya
# Enter the dream_job? Doctor
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
birth_year=input("Enter the birth_year?")
print(type(birth_year))
# Out:
# Enter the birth_year? 2006
# <class 'str'>

# %%
has_subscription=True
print(type(has_subscription))
# Out:
# <class 'bool'>

# %%
coffee_price=float(input("Enter the price of coffee?"))
print(type(coffee_price))
# Out:
# Enter the price of coffee? 3.50
# <class 'float'>

# %%
item_name=input("Enter the item_name?")
quantity_available=int(input("Enter the quantity?"))
print(type(item_name))
print(type(quantity_available))
# Out:
# Enter the item_name? Cake
# Enter the quantity? 10
# <class 'str'>
# <class 'int'>
